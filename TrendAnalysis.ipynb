# %%
# Linear and Polynomial Trend Analysis with Local AI
# I use alpha vantage for price data and openwebui/ollama for models like llama3.3 (hosted locally)

# %%
import json

# Load the config file
with open('keys.json', 'r') as keys_file:
    keys = json.load(keys_file)

# Access the API keys
AV_API_KEY = keys['AV_KEY']
O_API_KEY = keys['OPENWEB_KEY']
base_url = keys['OPENWEB_Base_URL']

# %%
import requests
import fireducks.pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from datetime import datetime, timedelta
import numpy as np
from openai import OpenAI


# Initialize the client with Open WebUI's OpenAI-compatible endpoint
client = OpenAI(
    base_url=base_url, 
    api_key=O_API_KEY
)

# %%
# Function to fetch daily stock data from Alpha Vantage
def fetch_stock_data(symbol, api_key):
    url = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={symbol}&apikey={api_key}&outputsize=full"
    r = requests.get(url)
    data = r.json()
    if 'Time Series (Daily)' not in data:
        raise ValueError("Failed to fetch data or API key is incorrect.")
    df = pd.DataFrame(data['Time Series (Daily)']).T
    df.index = pd.to_datetime(df.index)
    df = df.sort_index()
    df = df.rename(columns={'1. open': 'Open', '2. high': 'High', '3. low': 'Low', '4. close': 'Close', '5. adjusted close': 'Adj Close', '6. volume': 'Volume'})
    # Ensure 'Close' is numeric
    df['Adj Close'] = pd.to_numeric(df['Adj Close'], errors='coerce')
    return df[['Adj Close']]

# Input a ticker
symbol = input('Enter a ticker')  # Example stock symbol, you can change this
df = fetch_stock_data(symbol, AV_API_KEY)

# Prepare data for trend analysis
df['Date'] = df.index
df['Day'] = (df['Date'] - df['Date'].min())  / np.timedelta64(1,'D')
X = df['Day'].values.reshape(-1, 1)
y = df['Adj Close'].values

# Linear Trend
linear_reg = LinearRegression()
linear_reg.fit(X, y)
df['Linear_Trend'] = linear_reg.predict(X)

# Polynomial Trend (Quadratic for example)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)
df['Poly_Trend'] = poly_reg.predict(X_poly)

# Plotting 
plt.figure(figsize=(15, 7))
plt.gcf().set_facecolor('#1a1a1a') 
plt.gca().set_facecolor('#1a1a1a') 

# Styling 
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_color('white')
plt.gca().spines['bottom'].set_color('white')
plt.gca().tick_params(axis='x', colors='white', which='both')
plt.gca().tick_params(axis='y', colors='white', which='both')

# Plotting chart lines
plt.plot(df.index, df['Adj Close'], color='white', linewidth=1.5, label='Actual Price')
plt.plot(df.index, df['Linear_Trend'], color='#4CAF50', linewidth=1.2, label='Linear Trend')
plt.plot(df.index, df['Poly_Trend'], color='#FF9800', linewidth=1.2, label='Polynomial Trend')

# Adjusting title, labels for visibility and style
plt.title(f'{symbol} Stock Price with Trend Analysis', color='white', fontsize=16, fontweight='bold')
plt.xlabel('Date', color='white', fontsize=12)
plt.ylabel('Price ($)', color='white', fontsize=12)

# Legend styling
plt.legend(frameon=False, loc='upper left', labelcolor='white', fontsize=10)

# Adding a subtle grid for data readability
plt.grid(color='white', linestyle='--', linewidth=0.5, alpha=0.3)
plt.gca().set_xlim(df.index.min(), df.index.max())
plt.show()

# List of available models for analysis
available_models = ["llama3.3:latest", "llama3.2-vision:11b", "deepseek-r1:32b", "deepseek-r1:70b"]

print("Available models for analysis are:")
for i, model in enumerate(available_models, 1):
    print(f"{i}. {model}")

selection = int(input("Please enter the number of the model you want to use for analysis: "))
model_name = available_models[selection - 1]
print(f"You've selected {model_name} for analysis.")

# Function to use Llama API for trend insights
def use_llama_api(prompt):
    model = ""
    response = client.completions.create(
        model=model_name,
        prompt=prompt,
        # max_tokens=100  # Adjust as needed
    )
    return response.choices[0].text if response.choices else "No response from API."

# Now let's use Llama API for trend insights
trend_data = {
    "trend_linear": linear_reg.coef_[0],
    "trend_poly": poly_reg.coef_[1],  # Assuming quadratic term is the trend indicator here
    "last_price": df['Adj Close'].iloc[-1],
    "start_price": df['Adj Close'].iloc[0]
}

# Prepare the prompt for Llama API
prompt = f"For the stock {symbol}, linear trend coefficient is {trend_data['trend_linear']:.2f}, polynomial trend coefficient is {trend_data['trend_poly']:.2f}, the price started at ${trend_data['start_price']:.2f} and ended at ${trend_data['last_price']:.2f}. Analyze this trend data."

analysis = use_llama_api(prompt)
print(f"{model_name} Analysis:", analysis)

# Print some basic stats for the period
print(f"\nSimple Stats for {symbol} as of {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}:")
print(f"Start Price: ${df['Adj Close'].iloc[0]:.2f}")
print(f"End Price: ${df['Adj Close'].iloc[-1]:.2f}")
print(f"Price Change: ${(df['Adj Close'].iloc[-1] - df['Adj Close'].iloc[0]):.2f}")
print(f"Percentage Change: {(df['Adj Close'].iloc[-1] / df['Adj Close'].iloc[0] - 1) * 100:.2f}%")
# Out:
# Enter a ticker TSLA
# Available models for analysis are:
# 1. llama3.3:latest
# 2. llama3.2-vision:11b
# 3. deepseek-r1:32b
# 4. deepseek-r1:70b
# Please enter the number of the model you want to use for analysis:  1
# You've selected llama3.3:latest for analysis.
# llama3.3:latest Analysis: Based on the provided trend coefficients for the stock TSLA (Tesla, Inc.), we can analyze the trend data as follows:
#
# ### Linear Trend Coefficient: 0.06
# - A linear trend coefficient of 0.06 suggests that there is a positive linear relationship between time and the price of TSLA stock. This means that over the period analyzed, the stock's price has been increasing at a steady rate.
# - The small value of the coefficient indicates that the increase is gradual rather than dramatic on a per-unit-of-time basis.
#
# ### Polynomial Trend Coefficient: -0.04
# - The polynomial trend coefficient being negative (-0.04) suggests that there are periods within the time frame analyzed where the price does not follow a linear (straight line) progression. Instead, it might have experienced phases of faster and slower growth, or even temporary declines.
# - A polynomial model can capture more complex patterns than a simple linear one, such as acceleration or deceleration in the stock's price movement over time.
# - The negative sign could indicate that during some periods within the overall trend, there were downward movements or less intense upward movements, possibly reflecting market corrections, announcements affecting the company, or broader economic conditions.
#
# ### Initial and Final Stock Price
# - Starting at $1.59 and ending at $355.94 indicates a phenomenal growth in the stock's price over the analyzed period.
# - This significant increase suggests that despite any short-term fluctuations (possibly reflected by the polynomial coefficient), the overall trend for TSLA has been decidedly positive.
#
# ### Analysis Conclusion
# The combination of these coefficients with the starting and ending prices tells us several things about TSLA's performance during the period:
# 1. **Overall Growth**: The stock experienced substantial growth, as evidenced by the increase from $1.59 to $355.94.
# 2. **Linear Trend**: There is an underlying steady increase in price over time (linear trend coefficient of 0.06), indicating a consistent upward momentum in the long term.
# 3. **Complexity in Trend**: The polynomial trend coefficient (-0.04) suggests there might be periods of non-linear growth, meaning the stock's price didn't increase at the same rate all the time but had phases of different intensities of growth or decline.
#
# ### Investment and Market Insights
# For investors and market observers:
# - **Growth Potential**: TSLA has demonstrated significant long-term growth potential.
# - **Volatility**: The presence of a polynomial trend suggests that while there is an overall upward trajectory, there can be fluctuations, implying some level of volatility in the stock's price.
# - **Market Sentiment and Events**: Factors like technological advancements, government policies supportive of electric vehicles, company-specific news (e.g., financial reports, new product announcements), and broader market trends likely influence TSLA's stock price, contributing to both its linear growth trend and the polynomial fluctuations.
#
# In summary, TSLA has shown remarkable long-term growth with an underlying steady increase, interspersed with periods of varying growth rates or possible declines. This analysis underscores the importance of considering both short-term fluctuations and long-term trends when evaluating investment opportunities in stocks like TSLA.
#
# Simple Stats for TSLA as of 2025-02-13 18:15:28:
# Start Price: $1.59
# End Price: $355.94
# Price Change: $354.35
# Percentage Change: 22248.68%
